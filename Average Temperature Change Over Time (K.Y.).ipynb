# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as npdataset 
import numpy as np

# %%
dataset = pd.read_csv("Temperature Change.csv")
temperature_df = pd.read_csv("Temperature Change.csv")
temperatures = temperature_df['Value']

# %%
dataset.head()
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                3      Albania          7271
# 3          ET  Temperature change                3      Albania          7271
# 4          ET  Temperature change                4      Algeria          7271
#
#               Element  Months Code   Months  Year Code  Year Unit  Value Flag  \
# 0  Temperature change         7001  January       2019  2019   ?C  3.187   Fc
# 1  Temperature change         7001  January       2020  2020   ?C -0.472   Fc
# 2  Temperature change         7001  January       2019  2019   ?C -0.965   Fc
# 3  Temperature change         7001  January       2020  2020   ?C  1.157   Fc
# 4  Temperature change         7001  January       2019  2019   ?C -0.955   Fc
#
#   Flag Description
# ...

# %%
dataset.tail()
# Out:
#     Domain Code              Domain  Area Code (FAO)      Area  Element Code  \
# 473          ET  Temperature change              249     Yemen          7271
# 474          ET  Temperature change              251    Zambia          7271
# 475          ET  Temperature change              251    Zambia          7271
# 476          ET  Temperature change              181  Zimbabwe          7271
# 477          ET  Temperature change              181  Zimbabwe          7271
#
#                 Element  Months Code   Months  Year Code  Year Unit  Value  \
# 473  Temperature change         7001  January       2020  2020   ?C    NaN
# 474  Temperature change         7001  January       2019  2019   ?C  1.432
# 475  Temperature change         7001  January       2020  2020   ?C  1.691
# 476  Temperature change         7001  January       2019  2019   ?C  0.900
# 477  Temperature change         7001  January       2020  2020   ?C  1.321
#
#     Flag    Flag Description
# ...

# %%
df = pd.read_csv("Temperature Change.csv")

# %%
df['Area']
# Out:
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                                Albania
# 3                                                Albania
# 4                                                Algeria
# 5                                                Algeria
# 6                                         American Samoa
# 7                                         American Samoa
# 8                                                Andorra
# 9                                                Andorra
# 10                                                Angola
# 11                                                Angola
# 12                                              Anguilla
# 13                                              Anguilla
# 14                                            Antarctica
# 15                                            Antarctica
# ...

# %%
df['Element Code']
# Out:
# 0      7271
# 1      7271
# 2      7271
# 3      7271
# 4      7271
# 5      7271
# 6      7271
# 7      7271
# 8      7271
# 9      7271
# 10     7271
# 11     7271
# 12     7271
# 13     7271
# 14     7271
# 15     7271
# 16     7271
# 17     7271
# 18     7271
# 19     7271
# 20     7271
# 21     7271
# 22     7271
# 23     7271
# 24     7271
# 25     7271
# 26     7271
# 27     7271
# 28     7271
# 29     7271
# 30     7271
# 31     7271
# 32     7271
# 33     7271
# 34     7271
# 35     7271
# 36     7271
# 37     7271
# 38     7271
# 39     7271
# 40     7271
# 41     7271
# 42     7271
# 43     7271
# 44     7271
# 45     7271
# 46     7271
# 47     7271
# 48     7271
# 49     7271
# 50     7271
# 51     7271
# 52     7271
# 53     7271
# 54     7271
# 55     7271
# 56     7271
# 57     7271
# 58     7271
# 59     7271
# 60     7271
# 61     7271
# 62     7271
# 63     7271
# 64     7271
# 65     7271
# 66     7271
# 67     7271
# 68     7271
# 69     7271
# 70     7271
# ...

# %%
df['Year'] == '2020'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df
# Out:
#     Domain Code              Domain  Area Code (FAO)  \
# 0            ET  Temperature change                2
# 1            ET  Temperature change                2
# 2            ET  Temperature change                3
# 3            ET  Temperature change                3
# 4            ET  Temperature change                4
# 5            ET  Temperature change                4
# 6            ET  Temperature change                5
# 7            ET  Temperature change                5
# 8            ET  Temperature change                6
# 9            ET  Temperature change                6
# 10           ET  Temperature change                7
# 11           ET  Temperature change                7
# 12           ET  Temperature change              258
# 13           ET  Temperature change              258
# 14           ET  Temperature change               30
# 15           ET  Temperature change               30
# 16           ET  Temperature change                8
# ...

# %%
df.shape
# Out:
# (478, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       478 non-null    object
#  1   Domain            478 non-null    object
#  2   Area Code (FAO)   478 non-null    int64
#  3   Area              478 non-null    object
#  4   Element Code      478 non-null    int64
#  5   Element           478 non-null    object
#  6   Months Code       478 non-null    int64
#  7   Months            478 non-null    object
#  8   Year Code         478 non-null    int64
#  9   Year              478 non-null    int64
#  10  Unit              478 non-null    object
#  11  Value             453 non-null    float64
#  12  Flag              478 non-null    object
#  13  Flag Description  478 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 52.4+ KB

# %%
pd.set_option('display.max_columns', 14)

# %%
pd.set_option('display.max_rows', 478)

# %%
df[['Area', 'Year', 'Value']]
# Out:
#                                                   Area  Year  Value
# 0                                          Afghanistan  2019  3.187
# 1                                          Afghanistan  2020 -0.472
# 2                                              Albania  2019 -0.965
# 3                                              Albania  2020  1.157
# 4                                              Algeria  2019 -0.955
# 5                                              Algeria  2020 -0.033
# 6                                       American Samoa  2019  1.311
# 7                                       American Samoa  2020  1.011
# 8                                              Andorra  2019 -0.398
# 9                                              Andorra  2020  2.056
# 10                                              Angola  2019  1.079
# 11                                              Angola  2020  1.482
# 12                                            Anguilla  2019  0.519
# ...

# %%
df[['Area', 'Year', 'Value', 'Months']]
# Out:
#                                                   Area  Year  Value   Months
# 0                                          Afghanistan  2019  3.187  January
# 1                                          Afghanistan  2020 -0.472  January
# 2                                              Albania  2019 -0.965  January
# 3                                              Albania  2020  1.157  January
# 4                                              Algeria  2019 -0.955  January
# 5                                              Algeria  2020 -0.033  January
# 6                                       American Samoa  2019  1.311  January
# 7                                       American Samoa  2020  1.011  January
# 8                                              Andorra  2019 -0.398  January
# 9                                              Andorra  2020  2.056  January
# 10                                              Angola  2019  1.079  January
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       478 non-null    object
#  1   Domain            478 non-null    object
#  2   Area Code (FAO)   478 non-null    int64
#  3   Area              478 non-null    object
#  4   Element Code      478 non-null    int64
#  5   Element           478 non-null    object
#  6   Months Code       478 non-null    int64
#  7   Months            478 non-null    object
#  8   Year Code         478 non-null    int64
#  9   Year              478 non-null    int64
#  10  Unit              478 non-null    object
#  11  Value             453 non-null    float64
#  12  Flag              478 non-null    object
#  13  Flag Description  478 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 52.4+ KB

# %%
print(df.shape)
# Out:
# (478, 14)

# %%
df[['Area', 'Year', 'Value']][df['Year']== 2020]
# Out:
#                                                   Area  Year  Value
# 1                                          Afghanistan  2020 -0.472
# 3                                              Albania  2020  1.157
# 5                                              Algeria  2020 -0.033
# 7                                       American Samoa  2020  1.011
# 9                                              Andorra  2020  2.056
# 11                                              Angola  2020  1.482
# 13                                            Anguilla  2020  1.164
# 15                                          Antarctica  2020 -0.308
# 17                                 Antigua and Barbuda  2020  1.188
# 19                                           Argentina  2020  1.056
# 21                                             Armenia  2020  1.367
# 23                                               Aruba  2020  0.920
# 25                                           Australia  2020  1.493
# ...

# %%
# %matplotlib notebook

# %%
df.sort_values(by=['Value'], ascending=False, inplace=True)

# %%
df[['Area', 'Value']][df['Year']== 2020].plot(style=".")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
df[['Area', 'Value']][df['Year']== 2020].plot(x="Area", y= "Value", kind='scatter', rot=45, figsize=(20,10))
# Out:
# <img src="data:image/png;base64,..." width="2000">
# <AxesSubplot:xlabel='Area', ylabel='Value'>

# %%
df.groupby('Year').mean()[['Value']].plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="925.3333333333334">
# <AxesSubplot:xlabel='Year'>

# %%
plt.title("Average Change in Temperature over Time")
# Out:
# Text(0.5, 1.0, 'Average Change in Temperature over Time')

# %%
plt.xlabel("Year")
plt.ylabel("Temperature Change from Previous Year - Degrees")
# Out:
# Text(117.39583333333333, 0.5, 'Temperature Change from Previous Year - Degrees')

# %%
plt.savefig("YOY Average Change in Temperature.png")
