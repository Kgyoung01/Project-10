# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as npdataset 
import numpy as np

# %%
dataset = pd.read_csv("AIR_QUALITY_INDEX_TOPCOUNTRIES_CLEAN.csv")

# %%
dataset.head()
# Out:
#    Rank Country/Region  2021  2020  2019  2018     Population
# 0     1     Bangladesh  76.9  77.1  83.3  97.1    164,689,383
# 1     2       Pakistan  66.8  59.0  65.8  74.3    220,892,331
# 2     3          India  58.1  51.9  58.1  72.5  1,380,004,385
# 3     4        Bahrain  49.8  39.7  46.8  59.8      1,701,583
# 4     5          Nepal  46.0  39.2  44.5  54.1     29,136,808

# %%
dataset.tail()
# Out:
#     Rank Country/Region  2021  2020  2019  2018  Population
# 67    68        Iceland   6.1   7.2   5.5   5.0     341,250
# 68    69        Estonia   5.9   5.9   6.2   7.2   1,326,539
# 69    70      Australia   5.7   7.6   8.0   6.8  25,499,881
# 70    71        Finland   5.5   5.0   5.6   6.6   5,540,718
# 71    72    Puerto Rico   4.8   3.7  10.2  13.7   2,860,840

# %%
df = pd.read_csv("AIR_QUALITY_INDEX_TOPCOUNTRIES_CLEAN.csv")

# %%
df.head(10)
# Out:
#    Rank        Country/Region  2021  2020  2019  2018     Population
# 0     1            Bangladesh  76.9  77.1  83.3  97.1    164,689,383
# 1     2              Pakistan  66.8  59.0  65.8  74.3    220,892,331
# 2     3                 India  58.1  51.9  58.1  72.5  1,380,004,385
# 3     4               Bahrain  49.8  39.7  46.8  59.8      1,701,583
# 4     5                 Nepal  46.0  39.2  44.5  54.1     29,136,808
# 5     6            Uzbekistan  42.8  29.9  41.2  34.3     33,469,199
# 6     7           Afghanistan  37.5  46.5  58.8  61.8     38,928,341
# 7     8  United Arab Emirates  36.0  29.2  38.9  49.9      9,890,400
# 8     9             Indonesia  34.3  40.7  51.7  42.0    273,523,621
# 9    10              Mongolia  33.1  46.6  62.0  58.5      3,278,292

# %%
df.tail(10)
# Out:
#     Rank Country/Region  2021  2020  2019  2018  Population
# 62    63        Ireland   8.0   8.6  10.6   9.5   4,937,796
# 63    64         Norway   7.5   5.7   6.9   7.6   5,421,242
# 64    65       Portugal   7.1   9.1   9.3   9.4  10,196,707
# 65    66    New Zealand   6.8   7.0   7.5   7.7   4,822,233
# 66    67         Sweden   6.6   5.0   6.6   7.4  10,099,270
# 67    68        Iceland   6.1   7.2   5.5   5.0     341,250
# 68    69        Estonia   5.9   5.9   6.2   7.2   1,326,539
# 69    70      Australia   5.7   7.6   8.0   6.8  25,499,881
# 70    71        Finland   5.5   5.0   5.6   6.6   5,540,718
# 71    72    Puerto Rico   4.8   3.7  10.2  13.7   2,860,840

# %%
df[['Rank', 'Country/Region', '2020', '2019', 'Population']]
# Out:
#     Rank Country/Region  2020  2019     Population
# 0      1     Bangladesh  77.1  83.3    164,689,383
# 1      2       Pakistan  59.0  65.8    220,892,331
# 2      3          India  51.9  58.1  1,380,004,385
# 3      4        Bahrain  39.7  46.8      1,701,583
# 4      5          Nepal  39.2  44.5     29,136,808
# ..   ...            ...   ...   ...            ...
# 67    68        Iceland   7.2   5.5        341,250
# 68    69        Estonia   5.9   6.2      1,326,539
# 69    70      Australia   7.6   8.0     25,499,881
# 70    71        Finland   5.0   5.6      5,540,718
# 71    72    Puerto Rico   3.7  10.2      2,860,840
#
# [72 rows x 5 columns]

# %%
df.loc[0:25, ['Rank', 'Country/Region', '2020', '2019', 'Population']]
df.columns
# Out:
# Index(['Rank', 'Country/Region', '2021', '2020', '2019', '2018', 'Population'], dtype='object')

# %%
df.loc[0:25, ['Rank', 'Country/Region', '2020', '2019', 'Population']]
# Out:
#     Rank        Country/Region  2020  2019     Population
# 0      1            Bangladesh  77.1  83.3    164,689,383
# 1      2              Pakistan  59.0  65.8    220,892,331
# 2      3                 India  51.9  58.1  1,380,004,385
# 3      4               Bahrain  39.7  46.8      1,701,583
# 4      5                 Nepal  39.2  44.5     29,136,808
# 5      6            Uzbekistan  29.9  41.2     33,469,199
# 6      7           Afghanistan  46.5  58.8     38,928,341
# 7      8  United Arab Emirates  29.2  38.9      9,890,400
# 8      9             Indonesia  40.7  51.7    273,523,621
# 9     10              Mongolia  46.6  62.0      3,278,292
# 10    11                 China  34.7  39.1  1,439,323,774
# 11    12            Kazakhstan  21.9  23.6     18,776,707
# 12    13                  Iran  27.2  24.3     83,992,953
# 13    14                Kuwait  34.0  38.3      4,270,563
# 14    15                  Peru  17.9  23.3     32,971,846
# ...

# %%
df.loc[0:25, ['Rank', 'Country/Region', '2020', '2019', 'Population']]
# Out:
#     Rank        Country/Region  2020  2019     Population
# 0      1            Bangladesh  77.1  83.3    164,689,383
# 1      2              Pakistan  59.0  65.8    220,892,331
# 2      3                 India  51.9  58.1  1,380,004,385
# 3      4               Bahrain  39.7  46.8      1,701,583
# 4      5                 Nepal  39.2  44.5     29,136,808
# 5      6            Uzbekistan  29.9  41.2     33,469,199
# 6      7           Afghanistan  46.5  58.8     38,928,341
# 7      8  United Arab Emirates  29.2  38.9      9,890,400
# 8      9             Indonesia  40.7  51.7    273,523,621
# 9     10              Mongolia  46.6  62.0      3,278,292
# 10    11                 China  34.7  39.1  1,439,323,774
# 11    12            Kazakhstan  21.9  23.6     18,776,707
# 12    13                  Iran  27.2  24.3     83,992,953
# 13    14                Kuwait  34.0  38.3      4,270,563
# 14    15                  Peru  17.9  23.3     32,971,846
# ...

# %%
df["Population"].replace(',','', regex=True, inplace=True)
df["Population"]= df["Population"].astype(int)
df.sort_values(by=['Population'], ascending=False, inplace=True)
df
# Out:
#     Rank Country/Region  2021  2020  2019  2018  Population
# 10    11          China  32.6  34.7  39.1  41.2  1439323774
# 2      3          India  58.1  51.9  58.1  72.5  1380004385
# 57    58            USA  10.3   9.6   9.0   9.1   331002647
# 8      9      Indonesia  34.3  40.7  51.7  42.0   273523621
# 1      2       Pakistan  66.8  59.0  65.8  74.3   220892331
# ..   ...            ...   ...   ...   ...   ...         ...
# 41    42         Cyprus  14.8  15.8  19.7  17.6     1207361
# 32    33      Macao SAR  17.0  17.8  23.5  21.2      649342
# 59    60     Luxembourg   9.0   9.0   9.6  11.2      625976
# 47    48          Malta  13.5  11.8   9.4  11.0      441539
# 67    68        Iceland   6.1   7.2   5.5   5.0      341250
#
# [72 rows x 7 columns]

# %%
df[['Rank','Country/Region', 'Population', '2020']].head(50)
# Out:
#     Rank        Country/Region  Population  2020
# 10    11                 China  1439323774  34.7
# 2      3                 India  1380004385  51.9
# 57    58                   USA   331002647   9.6
# 8      9             Indonesia   273523621  40.7
# 1      2              Pakistan   220892331  59.0
# 46    47                Brazil   212559409  14.2
# 0      1            Bangladesh   164689383  77.1
# 49    50                Russia   145934460   9.3
# 26    27                Mexico   128932753  18.9
# 58    59                 Japan   126476458   9.8
# 21    22              Ethiopia   114963583  14.7
# 37    38           Philippines   109581085  12.8
# 20    21               Vietnam    97338583  28.0
# 24    25                Turkey    84339067  18.7
# 12    13                  Iran    83992953  27.2
# 56    57               Germany    83783945  10.1
# 23    24              Thailand    69799978  21.4
# 60    61        United Kingdom    67886004   8.3
# ...

# %%
# %matplotlib notebook

# %%
aqi = [77.1, 59.0, 51.9, 46.6, 46.5, 40.7, 40.6, 39.7, 39.2, 34.7, 34.0, 30.6, 29.9, 29.2, 28.0, 27.5, 27.2, 26.1, 24.3, 22.4, 21.9, 21.4, 21.2, 21.1, 20.0]
pop = [164689383, 220892331, 1380004385, 3278292, 38928341, 273523621, 3280815, 1701583, 29136808, 1439323774, 4270563, 2083380, 33469199, 9890400, 97338583, 6948445, 83992953,45741000, 8737370, 21413250, 18776707, 69799978, 4105268, 16718971, 1831000]
aqi2= df['2020']
pop2= df['Population']

# %%
plt.figure()
plt.xticks(rotation=90)
plt.scatter(pop2, aqi2, marker="o", facecolors="blue", edgecolors="black")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title("Air Quality Index vs Population")
plt.xlabel("Population in Billions")
plt.ylabel("Air Quality Index")
# Out:
# Text(70.58333333333334, 0.5, 'Air Quality Index')

# %%
plt.savefig("Air Quality Index vs Population.png")
